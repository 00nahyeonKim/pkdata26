# %% [markdown]
# ## 모듈

# %%
import mod1 as m1

# %%
# !python3 mod1.py
# Out:
# 5
# 2

# %%
print(m1.add(3, 4))
print(m1.add(8, 4))
print(m1.sub(3, 4))
print(m1.sub(9, 3))
# Out:
# 7
# 12
# -1
# 6

# %%
from mod1 import add, sub

print(add(55, 13))
print(sub(55, 13))
# Out:
# 68
# 42

# %%
import btc
# Out:
# 9억6559만589원

# %%
# !python3 mod1.py
# Out:
# 5
# 2

# %%
m1.__name__
# Out:
# 'mod1'

# %% [markdown]
# ### 1.2. 클래스나 변수 등을 포함한 모듈

# %%
import mod2

a = mod2.Math()

print(mod2.PI)
print(a.solv(10))
# Out:
# 3.141592
# 314.1592

# %%
from mod2 import Math, PI

b = Math()

print(PI)
print(b.solv(10))
# Out:
# 3.141592
# 314.1592

# %% [markdown]
# ### 1.3. 다른 디렉터리에 있는 모듈을 불러오는 방법

# %%
# %%sh
# mkdir ./mymod
# mv mod2.py ./mymod/mymod2.py

# %%
import mymod2

# %%
import sys

# sys.path.append("/home/knh/data/mymod/")

# %%
sys.path
# Out:
# ['/usr/lib/python312.zip',
#  '/usr/lib/python3.12',
#  '/usr/lib/python3.12/lib-dynload',
#  '',
#  '/home/knh/venv/lib/python3.12/site-packages',
#  '/home/knh/data/mymod/']

# %%
# %%sh
# mkdir game
# mkdir game/sound
# mkdir game/graphic
# mkdir game/play

# %%
# %%sh
# echo "" > /home/knh/data/game/__init__.py
# echo "" > /home/knh/data/game/sound/__init__.py
# echo "" > /home/knh/data/game/graphic/__init__.py
# echo "" > /home/knh/data/game/play/__init__.py

# %%
# %%sh
#
# echo "def echo_test():\n\tprint('echo')" > /home/knh/data/game/sound/echo.py
# echo "def render_test():\n\tprint('render')" > /home/knh/data/game/graphic/render.py

# %%
'''1번 방법'''
# import game.sound.echo

# game.sound.echo.echo_test()
'''2번 방법'''
# import game.sound.echo as ec

# ec.echo_test()

'''3번 방법'''
# from game.sound import echo
# echo.echo_test()

'''4번 방법'''
from game.sound.echo import echo_test
echo_test()
# Out:
# echo

# %%
f = open("/home/knh/data/game/__init__.py", "w")
st = '''VERSION = 4.5

def print_version_info():
    print(f"The version of this game is {VERSION}")
    '''
f.write(st)
f.close()

# %%
import game

print(game.VERSION)
game.print_version_info()
# Out:
# 4.5
# The version of this game is 4.5

# %%
st = '''from.graphic.render import render_test

VERSION = 4.7

def print_version_info():
    print(f"The version of this game is {VERSION}")

print("Initializing game ...")
    '''

with open("/home/knh/data/game/__init__.py", "w") as f:
    f.write(st)

# %%
import game
# Out:
# Initializing game ...

# %%
from game.graphic.render import render_test

# %%
from game.sound import *

# %%
with open("/home/knh/data/game/sound/__init__.py", "w") as f:
    f.write("__all__ = ['echo']")

# %%
echo.echo_test()
# Out:
# echo

# %%
st = '''from game.sound.echo import echo_test
def render_test():
    print("render")
    echo_test()
'''

with open("/home/knh/data/game/graphic/render.py", "w") as f:
    f.write(st)

# %%
from game.graphic.render import render_test
render_test()
# Out:
# render
# echo

# %%
try:
    4 / 0
except ZeroDivisionError as e:
    print(e)
# Out:
# division by zero

# %%
try:
    4 / 0
except ZeroDivisionError as e:
    print(e)
finally:
    print("응?")
# Out:
# division by zero
# 응?

# %%
try:
    a = [1,2]
    print(a[3])
    4/0
except ZeroDivisionError as e:
    print("0으로 나눌 수 없습니다.", e)
except IndexError as e:
    print("인덱싱 할 수 없습니다.", e)
# Out:
# 인덱싱 할 수 없습니다. list index out of range

# %%
try:
    a = [1,2]
    print(a[3])
    4/0
except ZeroDivisionError as e:
    print(e)
except IndexError as e:
    print(e)
# Out:
# list index out of range

# %%
try:
    age=int(input('나이를 입력하세요: '))
except:
    print('입력이 정확하지 않습니다.')
else:
    if age <= 18:
        print('미성년자는 출입금지입니다.')
    else:
        print('환영합니다.')
# Out:
# 나이를 입력하세요:  dd
# 입력이 정확하지 않습니다.

# %%
try:
    age=int(input('나이를 입력하세요: '))
except:
    print('입력이 정확하지 않습니다.')
else:
    try:
        if age <= 18:
            print('미성년자는 출입금지입니다.')
        else:
            print('환영합니다.')
    except:
        print("프로그램 점검요망.")
# Out:
# 나이를 입력하세요:  12
# 미성년자는 출입금지입니다.

# %%
students = ["김철수", "이영희", "박민수", "최유진"]

for (i, student) in enumerate(students, 1):
    try:
        with open(f"{student}_성적.txt", 'r') as f:
            score = f.read()
            print(f"{student}의 성적: {score}")
    except FileNotFoundError:
        print(f"{i}: {student}의 성적 파일이 없습니다. 건너뜁니다.")
        continue
# Out:
# 1: 김철수의 성적 파일이 없습니다. 건너뜁니다.
# 2: 이영희의 성적 파일이 없습니다. 건너뜁니다.
# 3: 박민수의 성적 파일이 없습니다. 건너뜁니다.
# 4: 최유진의 성적 파일이 없습니다. 건너뜁니다.

# %%
class Bird:
    def fly(self):
        raise NotImplementedError("설정해주세요.")

# %%
a = Bird()
a.fly()
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Cell In[42], line 2
#       1 a = Bird()
# ----> 2 a.fly()
#
# Cell In[41], line 3, in Bird.fly(self)
#       2 def fly(self):
# ----> 3     raise NotImplementedError("설정해주세요.")
#
# NotImplementedError: 설정해주세요.

# %%
class Eagle(Bird):
    def fly(self):
        print("난 진짜 난다")

# %%
e = Eagle()
e.fly()
# Out:
# 난 진짜 난다

# %%
class MyError(Exception):
    def __str__(self):
        return "나는 바보가 아냐! 코훌쩍..."
    pass

# %%
def say_nick(nick):
    if nick == '바보':
        raise MyError()
    print(nick)

# %%
try:
    print(say_nick("천사"))
    print(say_nick("바보"))
except MyError as e:
    print(e)
# Out:
# 천사
# None
# 나는 바보가 아냐! 코훌쩍...
