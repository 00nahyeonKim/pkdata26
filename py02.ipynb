# %% [markdown]
# ## 주요 자료형

# %% [markdown]
# ### 리스트 자료형

# %%
# 리스트 만들기
odd = [1, 3, 5, 7, 9]

# %%
a = []
b = [1, 2, 3]
c = ['Life', 'is', 'too', 'short']
d = [1, 2, 'Life', 'is']
e = [1, 2, ['Life', 'is']]

# %%
s = "spring"

a = [11, 22, 33, 44, 55]
print(a[0] + a[3])
# Out:
# 55

# %%
a = 'banana'
b = a

print(id(a))
print(id(b))

b = 'kiwi'

print(id(a))
print(id(b))

print(a)
print(b)
# Out:
# 138816236319008
# 138816236319008
# 138816236319008
# 138816236320640
# banana
# kiwi

# %%
aa = [11, 22, 33]
bb = aa

print(id(aa))
print(id(bb))

bb[0] = 33

print(id(aa))
print(id(bb))

print(aa)
print(bb)
# Out:
# 138816229790720
# 138816229790720
# 138816229790720
# 138816229790720
# [33, 22, 33]
# [33, 22, 33]

# %%
cc = []
print(cc, type(cc))
dd = list()
print(dd, type(dd))
# Out:
# [] <class 'list'>
# [] <class 'list'>
